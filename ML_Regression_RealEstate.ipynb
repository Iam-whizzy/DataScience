# %% [markdown]
# <a href="https://colab.research.google.com/github/Iam-whizzy/DataScience/blob/main/ML_Regression_RealEstate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("https://modcom.co.ke/new/realestate.csv")
data
# Out:
#      Unnamed: 0  Bedrooms  Bathrooms  Size    Price
# 0             0         3          3  2371   795000
# 1             1         4          3  2818   399000
# 2             2         4          3  3032   545000
# 3             3         4          4  3540   909000
# 4             4         3          1  1249   109900
# ..          ...       ...        ...   ...      ...
# 776         776         3          3  1605   319900
# 777         777         3          2  1877   495000
# 778         778         3          2  1104   372000
# 779         779         3          2  1975   589000
# 780         780         3          3  2392  1100000
#
# [781 rows x 5 columns]

# %%
# X: array[: 1:limit]

array = data.values
X = array[:,1:4]
X
# Out:
# array([[   3,    3, 2371],
#        [   4,    3, 2818],
#        [   4,    3, 3032],
#        ...,
#        [   3,    2, 1104],
#        [   3,    2, 1975],
#        [   3,    3, 2392]])

# %%
array = data.values
Y = array[:,4]
Y
# Out:
# array([ 795000,  399000,  545000,  909000,  109900,  324900,  192900,
#         215000,  999000,  319000,  350000,  249000,  299000,  235900,
#         348000,  314000,  399000,  599000,  299000,  425000, 1100000,
#        1500000,  110000,  200000,  134900,  250000,  950000,  239950,
#         170000,  285000,  279000,  219000,  155000,  389000,  340000,
#          95000,  140000, 1100000,  360000,  415000,  250000,  559000,
#         525000,  779000,  595000, 1150000,  550000,  500000,  279000,
#         375000,  330000,  199000,  165000, 1399000,  255000,  325000,
#         789000,  498000,  430000,  539900,  499000,  275000,  499000,
#         899000, 1045000,  774000,  239000,  195000,  325000,  320000,
#         275000,  329000,  140000,  409000,  167900,  325000,  119000,
#         245000,  259900,  495000,  399000,  329700,  199000,  149000,
#         225000,  195000,  359900,  799000,  595000,   89000,  129900,
# ...

# %%
from sklearn import model_selection

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# ALgorithms: Regression ALgorithms

from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB

# %%
# Pick the best model for training
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([ 219443.09193676,  263015.05683691,  351172.28814652,
#        1057728.41254533,  462582.659413  , 1030413.76055014,
#         226873.96967167,  161347.13873655,  339297.64244745,
#         219443.09193676,  226873.96967167,  971296.19983954,
#         273103.5831739 ,  936417.20384122,  683526.87719776,
#         128245.95609923,  267699.3084576 ,  199177.06175064,
#         380895.79908616,  928693.04769262,  442654.39639665,
#         187310.72205266,  370762.7839931 ,   77287.60222024,
#         172493.45533892,  501523.16744964,  -74796.60168779,
#        1455202.65860255,  295725.6775473 ,  290659.17000077,
#        1130633.32645818,  493657.23903172,   91099.87342577,
#         463978.21684815,  338630.41410901,  174857.8255273 ,
#         446076.55685041,  125845.40315587,  236624.72883888,
#         295440.7051347 ,  168395.76054562,  421765.62662817,
#         232278.24438797, 1047924.85862094,  928693.04769262,
# ...

# %%
Y_test
# Out:
# array([ 260000,  199900,  531905,  999000,  245000,  829900,  195000,
#         222600,  209000,  375000,  165000, 1195000,  225000,  774800,
#         349900,  359000,  279900,  195000,  299000,  750000,  239000,
#         150000,  259900,  158900,  200000,  325000,   67500, 1249000,
#         374800,  415000,  879000,  359900,  164900,  364000,   26500,
#         205000,  250000,  265000,  214000,  227900,   65900,  495000,
#         294900,  995000,  820000,  319900,  309000,  499000,  245000,
#        1290000,  309900,  249500,  375000,  509000,  299900,  360000,
#         260000,  240000,  549000,  278000, 1799000,  279000,  349900,
#         389000,  219000,  350000,  641900,  199000,  145000,   54500,
#         249000,  525000,  199000,  259000,  222900,  429000,  154000,
#         379000,  174900,  299000,  255000,  425000,  177000,  189900,
#         199000,  179000,  325000,  475000,  289000,  125000,  269000,
# ...

# %%
# Scientific Metric (Mean Squared Error) -> r2_score
from sklearn.metrics import r2_score
r2_score(predictions, Y_test) * 100
# Out:
# 32.37261696493534
