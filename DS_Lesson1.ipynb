# %% [markdown]
# <a href="https://colab.research.google.com/github/Iam-whizzy/PythonforDataScience/blob/main/DS_Lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas
#accessintg a number of records
#Do standard deviation
#check the number of a certain group
#group by a certain criteria
#checking for inconsistent or blank data - returns zero means data is consistent
#Create DFs
import pandas
data = pandas.read_csv("Employee.csv")
data
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
#Describe
data.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
#The Shape - gives us the number of columns and rows
data.shape
# Out:
# (4653, 9)

# %%
#access data from one column
data['Gender']
#give it a variable
gender = data['Gender']
gender
# Out:
# 0         Male
# 1       Female
# 2       Female
# 3         Male
# 4         Male
#          ...
# 4648    Female
# 4649      Male
# 4650      Male
# 4651      Male
# 4652      Male
# Name: Gender, Length: 4653, dtype: object

# %%
#multiple columns
subset = data[['Gender', 'Education', 'Age', 'City']]
subset
# Out:
#       Gender  Education  Age       City
# 0       Male  Bachelors   34  Bangalore
# 1     Female  Bachelors   28       Pune
# 2     Female  Bachelors   38  New Delhi
# 3       Male    Masters   27  Bangalore
# 4       Male    Masters   24       Pune
# ...      ...        ...  ...        ...
# 4648  Female  Bachelors   26  Bangalore
# 4649    Male    Masters   37       Pune
# 4650    Male    Masters   27  New Delhi
# 4651    Male  Bachelors   30  Bangalore
# 4652    Male  Bachelors   33  Bangalore
#
# [4653 rows x 4 columns]

# %%
#display the first five records
subset.head()
# Out:
#    Gender  Education  Age       City
# 0    Male  Bachelors   34  Bangalore
# 1  Female  Bachelors   28       Pune
# 2  Female  Bachelors   38  New Delhi
# 3    Male    Masters   27  Bangalore
# 4    Male    Masters   24       Pune

# %%
#first 100 records
subset = subset.head(100)
subset
# Out:
#     Gender  Education  Age       City
# 0     Male  Bachelors   34  Bangalore
# 1   Female  Bachelors   28       Pune
# 2   Female  Bachelors   38  New Delhi
# 3     Male    Masters   27  Bangalore
# 4     Male    Masters   24       Pune
# ..     ...        ...  ...        ...
# 95    Male        PHD   26  Bangalore
# 96  Female  Bachelors   31  Bangalore
# 97    Male  Bachelors   27  Bangalore
# 98  Female  Bachelors   29  Bangalore
# 99  Female  Bachelors   24  Bangalore
#
# [100 rows x 4 columns]

# %%
#Calculating the mean of the sample data
subset['Age'].mean()
# Out:
# 30.71

# %%
#we can do median, mode, sum, mean
subset['Age'].mode()
# Out:
# 0    34
# Name: Age, dtype: int64

# %%
#Group by
subset.groupby('Gender').size()
# Out:
# Gender
# Female    37
# Male      63
# dtype: int64

# %%
subset.groupby('Gender').mean()
# Out:
# <ipython-input-20-de1ae5248668>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   subset.groupby('Gender').mean()
#               Age
# Gender
# Female  29.135135
# Male    31.634921

# %%
subset.groupby(['Gender','Education']).size()
# Out:
# Gender  Education
# Female  Bachelors    32
#         Masters       5
# Male    Bachelors    42
#         Masters      13
#         PHD           8
# dtype: int64

# %%
#check for inconsistent data
data.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
#create DataFRame using Pandas
df =pandas.DataFrame(columns=['JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender', 'EverBenched', 'ExperienceInCurrentDomain','LeaveOrNot'],data=data)
df
# Out:
#       JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0            2017  Bangalore            3   34    Male          No
# 1            2013       Pune            1   28  Female          No
# 2            2014  New Delhi            3   38  Female          No
# 3            2016  Bangalore            3   27    Male          No
# 4            2017       Pune            3   24    Male         Yes
# ...           ...        ...          ...  ...     ...         ...
# 4648         2013  Bangalore            3   26  Female          No
# 4649         2013       Pune            2   37    Male          No
# 4650         2018  New Delhi            3   27    Male          No
# 4651         2012  Bangalore            3   30    Male         Yes
# 4652         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 0                             0           0
# 1                             3           1
# ...
