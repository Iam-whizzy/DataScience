# %% [markdown]
# <a href="https://colab.research.google.com/github/Iam-whizzy/PythonforDataScience/blob/main/MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Machine Learning:
#Artificial Intelligence: A process of building applications that possess human intelligence.
#Human Intelligence: able to learn(ML), understand env(computer vision), communicate(speech rec.)...
#ML: Deals with applications learning from data.
#Deep Learning: Deals with applications learning from other sources e.g images
# Categorized into:
# 1.Supervised learning
# 2.Unsupervised learning

# Supervised Learning: It involves learning from a labeled data
# Meaning into 2 aspects: Features/ Predictors/Independent Variables/ X
#                        :Outcomes/ Predicted/ Dependent/ Y
# In ML it is categorized into: Regression(Numbers), Classification(Text/ Categorical Data)
# GOAL: Prediction

# Unsupervised Learning: Deals with extracting underlying patterns in data
# Categorized into; Clustering & Association

# Classification: Predict Patient with Diabetes(PIMA Indians)
# Problem below is supervised because the outcome variable Y Is categorical

# %%
#Step: Read data from the source
import pandas
data = pandas.read_csv("https://modcom.co.ke/data/datasets/pima.csv")
data
# Out:
#      Children  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           6      148             72             35        0  33.6
# 1           1       85             66             29        0  26.6
# 2           8      183             64              0        0  23.3
# 3           1       89             66             23       94  28.1
# 4           0      137             40             35      168  43.1
# ..        ...      ...            ...            ...      ...   ...
# 763        10      101             76             48      180  32.9
# 764         2      122             70             27        0  36.8
# 765         5      121             72             23      112  26.2
# 766         1      126             60              0        0  30.1
# 767         1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age       Outcome
# 0                       0.627   50      Diabetic
# 1                       0.351   31  Not Diabetic
# 2                       0.672   32      Diabetic
# 3                       0.167   21  Not Diabetic
# 4                       2.288   33      Diabetic
# ..                        ...  ...           ...
# 763                     0.171   63  Not Diabetic
# 764                     0.340   27  Not Diabetic
# 765                     0.245   30  Not Diabetic
# 766                     0.349   47      Diabetic
# 767                     0.315   23  Not Diabetic
#
# [768 rows x 9 columns]

# %%
# Preprocessing and Data Analysis
# Statistical Analysis

data.describe()
# Out:
#          Children     Glucose  BloodPressure  SkinThickness     Insulin  \
# count  768.000000  768.000000     768.000000     768.000000  768.000000
# mean     3.845052  120.894531      69.105469      20.536458   79.799479
# std      3.369578   31.972618      19.355807      15.952218  115.244002
# min      0.000000    0.000000       0.000000       0.000000    0.000000
# 25%      1.000000   99.000000      62.000000       0.000000    0.000000
# 50%      3.000000  117.000000      72.000000      23.000000   30.500000
# 75%      6.000000  140.250000      80.000000      32.000000  127.250000
# max     17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# 25%     27.300000                  0.243750   24.000000
# 50%     32.000000                  0.372500   29.000000
# 75%     36.600000                  0.626250   41.000000
# max     67.100000                  2.420000   81.000000

# %%
data.corr()
# Out:
# <ipython-input-5-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                           Children   Glucose  BloodPressure  SkinThickness  \
# Children                  1.000000  0.129459       0.141282      -0.081672
# Glucose                   0.129459  1.000000       0.152590       0.057328
# BloodPressure             0.141282  0.152590       1.000000       0.207371
# SkinThickness            -0.081672  0.057328       0.207371       1.000000
# Insulin                  -0.073535  0.331357       0.088933       0.436783
# BMI                       0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction -0.033523  0.137337       0.041265       0.183928
# Age                       0.544341  0.263514       0.239528      -0.113970
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Children                 -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
#
#                                Age
# Children                  0.544341
# Glucose                   0.263514
# BloodPressure             0.239528
# SkinThickness            -0.113970
# Insulin                  -0.042163
# BMI                       0.036242
# DiabetesPedigreeFunction  0.033561
# Age                       1.000000

# %%
# Machine Learning
# Step 1 (only supervised learning)
# Divide data into features and outcome

array = data.values
array
# Out:
# array([[6, 148, 72, ..., 0.627, 50, 'Diabetic'],
#        [1, 85, 66, ..., 0.351, 31, 'Not Diabetic'],
#        [8, 183, 64, ..., 0.672, 32, 'Diabetic'],
#        ...,
#        [5, 121, 72, ..., 0.245, 30, 'Not Diabetic'],
#        [1, 126, 60, ..., 0.349, 47, 'Diabetic'],
#        [1, 93, 70, ..., 0.315, 23, 'Not Diabetic']], dtype=object)

# %%
# Features
X = array[:, 0:8]
X
# Out:
# array([[6, 148, 72, ..., 33.6, 0.627, 50],
#        [1, 85, 66, ..., 26.6, 0.351, 31],
#        [8, 183, 64, ..., 23.3, 0.672, 32],
#        ...,
#        [5, 121, 72, ..., 26.2, 0.245, 30],
#        [1, 126, 60, ..., 30.1, 0.349, 47],
#        [1, 93, 70, ..., 30.4, 0.315, 23]], dtype=object)

# %%
# Outcome
Y = array[:, 8]
Y
# Out:
# array(['Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic'],
#       dtype=object)

# %%
# Step 2: Split Data(X,Y) into Training(70%) and Testing(30%)
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# Step 3: Import Scientific Algorithms for training the model
# Classifiers

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
#Step 4: Cross-validation
# Process to determine the best model for a particular dataset

# %%
# Step 5: Training
model = DecisionTreeClassifier()
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Model Evaluation
# Accuracy in term of percentages
predictions = model.predict(X_test)
print(predictions)
# Out:
# array(['Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic'], dtype=object)

# %%
print(Y_test)
# Out:
# ['Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic']

# %%
# Accuracy Score: Metric for evaluating model predictions against Y_test
from sklearn.metrics import accuracy_score
print(f"The accuracy score {accuracy_score(predictions, Y_test) * 100}")
# Out:
# The accuracy score 70.995670995671

# %%
# Cross Validation
# Feature Engineering
# Over sampling....
# Bias

data.groupby('Outcome').size()
# Out:
# Outcome
# Diabetic        268
# Not Diabetic    500
# dtype: int64

# %%
# Prediction
features = [[17, 150, 100, 85, 101, 41, 1.4, 54]]
diagnosis = model.predict(features)
print(f"You are 70% likely to be{diagnosis}")
# Out:
# You are 70% likely to be['Not Diabetic']

# %%
data.describe()
# Out:
#          Children     Glucose  BloodPressure  SkinThickness     Insulin  \
# count  768.000000  768.000000     768.000000     768.000000  768.000000
# mean     3.845052  120.894531      69.105469      20.536458   79.799479
# std      3.369578   31.972618      19.355807      15.952218  115.244002
# min      0.000000    0.000000       0.000000       0.000000    0.000000
# 25%      1.000000   99.000000      62.000000       0.000000    0.000000
# 50%      3.000000  117.000000      72.000000      23.000000   30.500000
# 75%      6.000000  140.250000      80.000000      32.000000  127.250000
# max     17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# 25%     27.300000                  0.243750   24.000000
# 50%     32.000000                  0.372500   29.000000
# 75%     36.600000                  0.626250   41.000000
# max     67.100000                  2.420000   81.000000

# %%
data = pandas.read_csv("https://modcom.co.ke/data/datasets/bank.csv")
data
# Out:
#     Gender Married     Education Self_Employed  Applicant_Income  Loan_Amount  \
# 0     Male      No  Not Graduate            No              5849          NaN
# 1     Male      No  Not Graduate            No              4583        128.0
# 2     Male      No  Not Graduate           Yes              3000         66.0
# 3     Male     Yes  Not Graduate            No              2583        120.0
# 4     Male      No  Not Graduate            No              6000        141.0
# 5     Male      No  Not Graduate           Yes              5417        267.0
# 6     Male     Yes  Not Graduate            No              2333         95.0
# 7     Male      No  Not Graduate            No              3036        158.0
# 8     Male      No  Not Graduate            No              4006        168.0
# 9     Male     Yes  Not Graduate            No              2841        349.0
# 10    Male     Yes      Graduate            No              3200         70.0
# 11    Male     Yes      Graduate           NaN              9546        109.0
# 12    Male      No      Graduate            No              9547        200.0
# 13    Male     Yes      Graduate            No              9548        114.0
# 14    Male      No      Graduate            No              9549         17.0
# 15    Male     Yes      Graduate            No              9550        125.0
# 16    Male      No      Graduate            No              6995        100.0
# 17    Male     Yes      Graduate            No              6996         76.0
# 18    Male     Yes      Graduate            No              6997        133.0
# 19  Female      No      Graduate           NaN              6998        115.0
# 20  Female      No      Graduate            No              6999        104.0
# 21  Female     Yes      Graduate            No              7000        315.0
# 22  Female     Yes      Graduate            No              9557        116.0
# 23  Female     Yes      Graduate            No              9558        112.0
# 24  Female      No      Graduate           NaN              9559        151.0
# 25  Female      No      Graduate           Yes              9560        191.0
# 26  Female     Yes  Not Graduate            No              2799        122.0
# 27  Female     Yes  Not Graduate            No              4226        110.0
# 28  Female     Yes  Not Graduate            No              1442         35.0
# 29  Female     Yes  Not Graduate           NaN              3750        120.0
# 30  Female      No  Not Graduate           NaN              4166        201.0
# 31  Female      No  Not Graduate            No              3167         74.0
# 32  Female     Yes      Graduate           Yes              4692        106.0
# 33  Female      No      Graduate            No              4998        114.0
# 34  Female      No      Graduate            No              4999        320.0
# 35  Female      No      Graduate            No              5000          NaN
# 36  Female      No  Not Graduate            No              1828        100.0
# 37  Female      No  Not Graduate            No              3667        144.0
# 38  Female      No  Not Graduate            No              4166        184.0
#
#             Loan_Status
# 0            Get A Loan
# 1   Does Not Get A Loan
# 2            Get A Loan
# 3            Get A Loan
# 4            Get A Loan
# 5            Get A Loan
# 6            Get A Loan
# 7   Does Not Get A Loan
# 8            Get A Loan
# 9   Does Not Get A Loan
# 10           Get A Loan
# 11           Get A Loan
# 12           Get A Loan
# 13  Does Not Get A Loan
# 14           Get A Loan
# 15           Get A Loan
# 16           Get A Loan
# 17  Does Not Get A Loan
# 18  Does Not Get A Loan
# 19           Get A Loan
# 20  Does Not Get A Loan
# 21           Get A Loan
# 22  Does Not Get A Loan
# 23  Does Not Get A Loan
# 24  Does Not Get A Loan
# 25           Get A Loan
# 26           Get A Loan
# 27           Get A Loan
# 28  Does Not Get A Loan
# 29           Get A Loan
# 30  Does Not Get A Loan
# 31  Does Not Get A Loan
# 32  Does Not Get A Loan
# 33           Get A Loan
# 34  Does Not Get A Loan
# 35           Get A Loan
# 36  Does Not Get A Loan
# 37           Get A Loan
# 38           Get A Loan

# %%
data['Gender'].replace({'Male': 0, 'Female': 1}, inplace = True)
data['Married'].replace({'No': 0, 'Yes': 1}, inplace = True)
data['Education'].replace({'Not Graduate': 0, 'Graduate': 1}, inplace = True)
data
# Out:
#     Gender  Married  Education Self_Employed  Applicant_Income  Loan_Amount  \
# 0        0        0          0            No              5849          NaN
# 1        0        0          0            No              4583        128.0
# 2        0        0          0           Yes              3000         66.0
# 3        0        1          0            No              2583        120.0
# 4        0        0          0            No              6000        141.0
# 5        0        0          0           Yes              5417        267.0
# 6        0        1          0            No              2333         95.0
# 7        0        0          0            No              3036        158.0
# 8        0        0          0            No              4006        168.0
# 9        0        1          0            No              2841        349.0
# 10       0        1          1            No              3200         70.0
# 11       0        1          1           NaN              9546        109.0
# 12       0        0          1            No              9547        200.0
# 13       0        1          1            No              9548        114.0
# 14       0        0          1            No              9549         17.0
# 15       0        1          1            No              9550        125.0
# 16       0        0          1            No              6995        100.0
# 17       0        1          1            No              6996         76.0
# 18       0        1          1            No              6997        133.0
# 19       1        0          1           NaN              6998        115.0
# 20       1        0          1            No              6999        104.0
# 21       1        1          1            No              7000        315.0
# 22       1        1          1            No              9557        116.0
# 23       1        1          1            No              9558        112.0
# 24       1        0          1           NaN              9559        151.0
# 25       1        0          1           Yes              9560        191.0
# 26       1        1          0            No              2799        122.0
# 27       1        1          0            No              4226        110.0
# 28       1        1          0            No              1442         35.0
# 29       1        1          0           NaN              3750        120.0
# 30       1        0          0           NaN              4166        201.0
# 31       1        0          0            No              3167         74.0
# 32       1        1          1           Yes              4692        106.0
# 33       1        0          1            No              4998        114.0
# 34       1        0          1            No              4999        320.0
# 35       1        0          1            No              5000          NaN
# 36       1        0          0            No              1828        100.0
# 37       1        0          0            No              3667        144.0
# 38       1        0          0            No              4166        184.0
#
#             Loan_Status
# 0            Get A Loan
# 1   Does Not Get A Loan
# 2            Get A Loan
# 3            Get A Loan
# 4            Get A Loan
# 5            Get A Loan
# 6            Get A Loan
# 7   Does Not Get A Loan
# 8            Get A Loan
# 9   Does Not Get A Loan
# 10           Get A Loan
# 11           Get A Loan
# 12           Get A Loan
# 13  Does Not Get A Loan
# 14           Get A Loan
# 15           Get A Loan
# 16           Get A Loan
# 17  Does Not Get A Loan
# 18  Does Not Get A Loan
# 19           Get A Loan
# 20  Does Not Get A Loan
# 21           Get A Loan
# 22  Does Not Get A Loan
# 23  Does Not Get A Loan
# 24  Does Not Get A Loan
# 25           Get A Loan
# 26           Get A Loan
# 27           Get A Loan
# 28  Does Not Get A Loan
# 29           Get A Loan
# 30  Does Not Get A Loan
# 31  Does Not Get A Loan
# 32  Does Not Get A Loan
# 33           Get A Loan
# 34  Does Not Get A Loan
# 35           Get A Loan
# 36  Does Not Get A Loan
# 37           Get A Loan
# 38           Get A Loan
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['Gender'].plot(kind='hist', bins=20, title='Gender')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data['Married'].plot(kind='hist', bins=20, title='Married')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data['Education'].plot(kind='hist', bins=20, title='Education')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data['Applicant_Income'].plot(kind='hist', bins=20, title='Applicant_Income')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# data.groupby('Self_Employed').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# data.groupby('Loan_Status').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data.plot(kind='scatter', x='Gender', y='Married', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data.plot(kind='scatter', x='Married', y='Education', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data.plot(kind='scatter', x='Education', y='Applicant_Income', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data.plot(kind='scatter', x='Applicant_Income', y='Loan_Amount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Gender']
#   ys = series['Married']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = data.sort_values('Gender', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Self_Employed')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Self_Employed', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Gender')
# _ = plt.ylabel('Married')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Gender']
#   ys = series['Married']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = data.sort_values('Gender', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Loan_Status')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Loan_Status', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Gender')
# _ = plt.ylabel('Married')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Gender']
#   ys = series['Education']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = data.sort_values('Gender', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Self_Employed')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Self_Employed', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Gender')
# _ = plt.ylabel('Education')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Gender']
#   ys = series['Education']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = data.sort_values('Gender', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Loan_Status')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Loan_Status', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Gender')
# _ = plt.ylabel('Education')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['Gender'].plot(kind='line', figsize=(8, 4), title='Gender')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# data['Married'].plot(kind='line', figsize=(8, 4), title='Married')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# data['Education'].plot(kind='line', figsize=(8, 4), title='Education')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# data['Applicant_Income'].plot(kind='line', figsize=(8, 4), title='Applicant_Income')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Loan_Status'].value_counts()
#     for x_label, grp in data.groupby('Self_Employed')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Self_Employed')
# _ = plt.ylabel('Loan_Status')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(data['Self_Employed'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(data, x='Gender', y='Self_Employed', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(data['Loan_Status'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(data, x='Gender', y='Loan_Status', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(data['Self_Employed'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(data, x='Married', y='Self_Employed', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(data['Loan_Status'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(data, x='Married', y='Loan_Status', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
