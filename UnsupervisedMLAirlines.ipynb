# %% [markdown]
# <a href="https://colab.research.google.com/github/Iam-whizzy/DataScience/blob/main/UnsupervisedMLAirlines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("https://modcom.co.ke/data/datasets/AirlinesCluster.csv")
data
# Out:
#       Balance  QualMiles  BonusMiles  BonusTrans  FlightMiles  FlightTrans  \
# 0       28143          0         174           1            0            0
# 1       19244          0         215           2            0            0
# 2       41354          0        4123           4            0            0
# 3       14776          0         500           1            0            0
# 4       97752          0       43300          26         2077            4
# ...       ...        ...         ...         ...          ...          ...
# 3994    18476          0        8525           4          200            1
# 3995    64385          0         981           5            0            0
# 3996    73597          0       25447           8            0            0
# 3997    54899          0         500           1          500            1
# 3998     3016          0           0           0            0            0
#
#       DaysSinceEnroll
# 0                7000
# ...
